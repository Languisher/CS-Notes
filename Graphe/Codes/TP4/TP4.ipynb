# %% [markdown]
# # TP4 : les parcours en profondeur
#
# L'objectf est de comprendre comment fonctionne un parcours un largeur autour de quelques exemples. Nous mettrons en avant les différences avec un parcours en largeur.
#
#
#
# Dans la suite du TP, on générera des graphe alétoirement à l'aide de `fast_gnp_random_graph` :

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

# %%
G=nx.fast_gnp_random_graph(20,0.1)
nx.draw(G,with_labels=True)
plt.savefig("graphe1.png")

# %% [markdown]
# ## I) Parcours en profondeur.
#
#
#
# ### Exercice n°1 Manipulation des parcours en profondeur
#
# Rappeler sur le graphe suivant les étapes du parcours en profondeur en partant du sommet 1.
#
# ![graphe1.png](graphe1.png)

# %% [markdown]
# ### Exercice n°2 (parcours en profondeur).
#
# Créer un programme `parcoursprof(G,x)` qui prend en entrée un graphe et un sommet. Il affiche le même graphe. Les sommets sont formés de l'ancien numéro de sommet ainsi que l'ordre de traitement. Si un sommet n'est pas traité, on écrira `sommet non traité`

# %% [markdown]
# ### Exercice n°2 ( parcours en profondeur et test de connexité)
#
#
# Plutôt que d'utiliser un marqueur, on va différentier dans nos programmes deux listes : `listevisitee` et `listenontraitee` Des sommes à traiter.
#
# 1. Programmer une fonction `compconnexe(G,x)` qui prend en entrée un graphe $G$ et un sommet $x$. Le programme renvoie la liste des sommets de la composante connexe de $x$ à l'aide d'un parcours en profondeur.
#
# 1. Programmer une fonction `estconnexe(G)` qui prend en entrée un graphe $G$ et renvoie True si $G$ est connexe False sinon.
#
# 1. Programmer une fonction `comp_connexe(G)` qui prend en entrée un graphe $G$ et renvoie la liste des composantes connexes. On tracera aussi le graphe $G$ avec des couleurs différentes pour chacune des composantes connexes.

# %% [markdown]
# ### Exercice n°3 (coloriage des composantes connexes)
#
# 1. Créer un dictionnaire `coloriage(G)` qui à chaque sommet associe son numéro de composante connexe
#
# 2. Créer une fonction `coloriagecompconnexe(G)` comp connexe qui prend en entrée un graphe $G$ et renvoie le graphe de $G$ dont chacune des composantes connexes est coloriée avec une couleur différente.

# %% [markdown]
# ### Exercice n°4 (exercice sur les 2 coloriages)
#
# On dit qu'un graphe est 2 coloriables, si il existe un coloriage des sommets à l'aide de 2 couleurs. Si 2 sommets sont joints par une arête, ils ont une couleur différente.
#
# 1. Proposez un code `2coloriage(G)` qui prend en entrée un graphe connexe. L'algorithme vérifie si le graphe est 2 coloriables et renvoient le graphe colorié si c'est le cas.
#
# 2. Tester votre code sur le graphe suivant :
# ![graphe2.png](graphe2.png)

# %% [markdown]
# ### Exercice n°5 (parcours en profondeur version rec)
#
# On souhaite programmer le parcours en profondeur de façon itérative à chaque étape on doit prendre en charge la liste des sommets traités et sommets non-traités. La démarche du parcours en largeur est itérative.
#
# 1. Créer un programme `parcoursprofrec(G,visité,S)` qui prend en entrée un graphe $G$, la liste des sommets visités et un sommet $S$.
#
# 1. Créer un programme `existe_chemin(G,S1,S2)` qui prend en entrée un graphe $G$, deux sommets $S_1$ et $S_2$ est vérifie si il existe un chemin allant de $S_1$ à $S_2$.

# %% [markdown]
# ### Exercice n°6 : teste de cyclicité.
#
# 1. Programmer à l'aide d'un parcours en profondeur, un programme `est_acyclique(G,s)` qui prend en entrée un graphe $G$ un sommet $s$. Le programme renvoie True si il n'y a pas de cycle dans la composante connexe de $s$, False sinon.
#
# 2. Programmer à l'aide d'un parcours en profondeur, un programme `est_acyclique2(G)` qui prend en entrée un graphe $G$ Le programme renvoie True si il n'y a pas de cycle dans une des composantes connexes de $G$, False sinon.
